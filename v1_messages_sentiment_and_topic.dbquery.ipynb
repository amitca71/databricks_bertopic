-- %%
create or replace view v1_messages_sentiment_and_topic as 
(with t_messages as (select id, text,translated, incitement.pred_label incitment_label  from bertopic_input),
t_message_topic as (select execution_id, timestamp,id, model,layer, father_topic, topic from topics)
select * from t_message_topic inner join t_messages using (id))
