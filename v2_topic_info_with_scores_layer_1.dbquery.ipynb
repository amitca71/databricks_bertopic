-- %%
create or replace view v2_topic_info_with_scores_layer_1 as
(select execution_id, full_topic, father_topic, topic, layer ,count,score, title, description from v1_topic_info_with_scores_and_names
where score>3 or layer=1)
